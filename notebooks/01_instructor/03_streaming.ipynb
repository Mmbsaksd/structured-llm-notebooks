# %% [markdown]
# # Instructor Streaming — Live Extraction for Responsive UIs
#
# **Week 1 | Notebook 3 of 4**
#
# **What you'll learn:**
# - `Partial[Model]` — streaming partial objects
# - Building a live-updating extraction UI (Gradio)
# - `create_iterable` — streaming lists of entities
# - Async streaming — processing multiple documents in parallel
# - Streaming from Anthropic vs OpenAI (API differences)
# - Latency benchmarks: streaming vs. non-streaming UX
#
# **Runtime:** ~45 minutes

# %%
# 💰 COST ESTIMATE
from src.cost_tracker import print_cost_warning

print_cost_warning("01_instructor/03_streaming.ipynb")
# Out:
# 💰 COST ESTIMATE
# ----------------------------------------
# Notebook:  01_instructor/03_streaming.ipynb
# Task:      Streaming partial objects
# Calls:     ~8
#
# With GPT-4o:       $0.08 USD
# With GPT-4o-mini:  $0.01 USD (10x cheaper)
# With Ollama:       $0.00 USD (free, local)
#
# 💡 TIP: Set USE_SMALL_MODEL=true or USE_OLLAMA=true in .env to save money.
# ----------------------------------------

# %% [markdown]
# ## 1. Setup

# %%
import instructor
from pydantic import BaseModel

from src.config import get_instructor_client, get_model

client = get_instructor_client()

# %% [markdown]
# ## 2. Partial Streaming — Yields Incomplete Objects

# %%
class Order(BaseModel):
    customer: str
    items: list[str]
    total: float
    status: str


order_text = """
Order from John Doe: 2x MacBook Pro, 1x AirPods Pro.
Total: $4,298. Status: confirmed.
"""

print("Streaming partial objects:\n")
for partial_order in client.chat.completions.create_partial(
    model=get_model(),
    response_model=Order,
    messages=[{"role": "user", "content": f"Extract order: {order_text}"}],
):
    # Each iteration gives a progressively more complete object
    print(
        f"Customer: {partial_order.customer or '...'} | Items: {len(partial_order.items or [])} | Total: {partial_order.total or '...'}"
    )
# Out:
# Streaming partial objects:
#
# Customer: ... | Items: 0 | Total: ...
# Customer: ... | Items: 0 | Total: ...
# Customer: ... | Items: 0 | Total: ...
# Customer: ... | Items: 0 | Total: ...
# Customer: John | Items: 0 | Total: ...
# Customer: John Doe | Items: 0 | Total: ...
# Customer: John Doe | Items: 0 | Total: ...
# Customer: John Doe | Items: 0 | Total: ...
# Customer: John Doe | Items: 1 | Total: ...
# Customer: John Doe | Items: 1 | Total: ...
# Customer: John Doe | Items: 1 | Total: ...
# Customer: John Doe | Items: 1 | Total: ...
# Customer: John Doe | Items: 2 | Total: ...
# Customer: John Doe | Items: 2 | Total: ...
# Customer: John Doe | Items: 2 | Total: ...
# Customer: John Doe | Items: 2 | Total: ...
# Customer: John Doe | Items: 3 | Total: ...
# Customer: John Doe | Items: 3 | Total: ...
# Customer: John Doe | Items: 3 | Total: ...
# Customer: John Doe | Items: 3 | Total: ...
# Customer: John Doe | Items: 3 | Total: ...
# Customer: John Doe | Items: 3 | Total: ...
# Customer: John Doe | Items: 3 | Total: ...
# Customer: John Doe | Items: 3 | Total: ...
# Customer: John Doe | Items: 3 | Total: 429
# Customer: John Doe | Items: 3 | Total: 4298
# Customer: John Doe | Items: 3 | Total: 4298
# Customer: John Doe | Items: 3 | Total: 4298
# Customer: John Doe | Items: 3 | Total: 4298
# Customer: John Doe | Items: 3 | Total: 4298
# Customer: John Doe | Items: 3 | Total: 4298.0

# %% [markdown]
# ## 3. Streaming Lists — Extract Multiple Items Progressively

# %%
class LineItem(BaseModel):
    product_name: str
    quantity: int
    unit_price: float


invoice_text = """
Invoice #1234
- MacBook Pro x2 @ $1,999 each
- AirPods Pro x1 @ $249
- USB-C Cable x3 @ $19 each
"""

print("Streaming individual line items:\n")
for item in client.chat.completions.create_iterable(
    model=get_model(),
    response_model=LineItem,
    messages=[{"role": "user", "content": f"Extract all line items: {invoice_text}"}],
):
    print(f"  Got: {item.product_name} x{item.quantity} @ ${item.unit_price}")
# Out:
# Streaming individual line items:
#
#   Got: MacBook Pro x2 @ $1999.0
#   Got: AirPods Pro x1 @ $249.0
#   Got: USB-C Cable x3 @ $19.0

# %% [markdown]
# ## 4. Live-Updating Extraction UI with Gradio

# %%
import gradio as gr


def extract_with_streaming(text: str):
    """Stream extraction results to Gradio UI."""

    class ExtractedInfo(BaseModel):
        name: str | None = None
        company: str | None = None
        amount: float | None = None
        date: str | None = None

    result_text = ""
    for partial in client.chat.completions.create_partial(
        model=get_model(),
        response_model=ExtractedInfo,
        messages=[{"role": "user", "content": f"Extract info from: {text}"}],
    ):
        result_text = partial.model_dump_json(indent=2)
        yield result_text


# Create Gradio interface
demo = gr.Interface(
    fn=extract_with_streaming,
    inputs=gr.Textbox(label="Input Text", value="John from Acme Corp paid $500 on 2025-01-15"),
    outputs=gr.Textbox(label="Extracted Info"),
    title="Live Extraction with Instructor Streaming",
    description="Type text and watch the structured data fill in live!",
)

# Uncomment to launch:
demo.launch()

print("✅ Gradio demo ready. Uncomment demo.launch() to start the UI.")
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# ✅ Gradio demo ready. Uncomment demo.launch() to start the UI.

# %% [markdown]
# ## 5. Async Streaming — Processing Multiple Documents

# %%
import asyncio

from src.config import get_async_openai_client, get_model

async_client = instructor.from_openai(get_async_openai_client())


class User(BaseModel):
    name: str
    age: int
    city: str


async def extract_user(text: str) -> User:
    return await async_client.chat.completions.create(
        model=get_model(),
        response_model=User,
        messages=[{"role": "user", "content": text}],
    )


texts = [
    "Alice, 30, lives in New York",
    "Bob is 25 and from San Francisco",
    "Carol, 35, based in Chicago",
]


async def process_batch():
    tasks = [extract_user(t) for t in texts]
    results = await asyncio.gather(*tasks)
    return results


results = await process_batch()
for user in results:
    print(f"{user.name}, {user.age}, {user.city}")
# Out:
# Alice, 30, New York
# Bob, 25, San Francisco
# Carol, 35, Chicago

# %% [markdown]
# ## 6. Streaming API Differences: OpenAI vs Anthropic

# %%
# The ONLY difference between providers is how the client is created.
# The extraction code below is literally the same function for both.

class Person(BaseModel):
    name: str
    age: int
    city: str


def stream_extract(client, model: str, text: str):
    """Provider-agnostic streaming extraction — same code for everyone."""
    for partial in client.chat.completions.create_partial(
        model=model,
        response_model=Person,
        messages=[{"role": "user", "content": text}],
        max_tokens=1024,  # required by Anthropic; OpenAI accepts it too
    ):
        yield partial


text = "Alice, 30, lives in New York"

# Different clients, different models — same call site.
# Providers without a key in .env are skipped, so the cell always runs.
results = {}
for provider in ("openai", "anthropic", "gemini", "groq"):
    try:
        c = get_instructor_client(provider)
        results[provider] = list(stream_extract(c, get_model(provider), text))[-1]
        print(f"{provider.capitalize()} ({get_model(provider)}): {results[provider].model_dump_json()}")
    except ValueError as e:
        print(f"{provider.capitalize()}: skipped — no API key in .env")

# Same schema in, same structured objects out — regardless of provider
signatures = {
    p: {k: type(v).__name__ for k, v in r.model_dump().items()} for p, r in results.items()
}
assert len(set(map(frozenset, signatures.values()))) <= 1, f"Mismatched outputs: {signatures}"
print("\n✅ Identical structured output — Instructor abstracts streaming differences between providers")
print("   Same code works for OpenAI, Anthropic, Gemini, Groq, and local models")
# Out:
# API call failed on attempt 1: Error code: 401 - {'error': {'message': 'Incorrect API key provided: sk-your-***********here. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'code': 'invalid_api_key', 'param': None}, 'status': 401}
# Max retries exceeded. Total attempts: 1, Last error: Error code: 401 - {'error': {'message': 'Incorrect API key provided: sk-your-***********here. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'code': 'invalid_api_key', 'param': None}, 'status': 401}
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# File ~\Desktop\vscode\paul\structured-llm-notebooks\.venv\Lib\site-packages\instructor\v2\core\retry.py:295, in retry_sync_v2(func, response_model, provider, mode, context, max_retries, args, kwargs, strict, hooks, token_budget)
#     294 try:
# --> 295     for attempt in max_retries_instance:
#     296         with attempt:
#
# File ~\Desktop\vscode\paul\structured-llm-notebooks\.venv\Lib\site-packages\tenacity\__init__.py:438, in BaseRetrying.__iter__(self)
#     437 while True:
# --> 438     do = self.iter(retry_state=retry_state)
#     439     if isinstance(do, DoAttempt):
#
# File ~\Desktop\vscode\paul\structured-llm-notebooks\.venv\Lib\site-packages\tenacity\__init__.py:371, in BaseRetrying.iter(self, retry_state)
#     370 for action in self.iter_state.actions:
# --> 371     result = action(retry_state)
#     372 return result
#
# File ~\Desktop\vscode\paul\structured-llm-notebooks\.venv\Lib\site-packages\tenacity\__init__.py:393, in BaseRetrying._post_retry_check_actions.<locals>.<lambda>(rs)
#     392 if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 393     self._add_action_func(lambda rs: rs.outcome.result())
#     394     return
#
# File ~\AppData\Roaming\uv\python\cpython-3.12.9-windows-x86_64-none\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#
# File ~\AppData\Roaming\uv\python\cpython-3.12.9-windows-x86_64-none\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     400 try:
# --> 401     raise self._exception
#     402 finally:
#     403     # Break a reference cycle with the exception in self._exception
#
# File ~\Desktop\vscode\paul\structured-llm-notebooks\.venv\Lib\site-packages\instructor\v2\core\retry.py:304, in retry_sync_v2(func, response_model, provider, mode, context, max_retries, args, kwargs, strict, hooks, token_budget)
#     303 try:
# --> 304     response = func(*args, **kwargs)
#     305 except IncompleteOutputException:
#
# File ~\Desktop\vscode\paul\structured-llm-notebooks\.venv\Lib\site-packages\openai\_utils\_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# File ~\Desktop\vscode\paul\structured-llm-notebooks\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py:1296, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, moderation, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_options, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1295 validate_response_format(response_format)
# -> 1296 return self._post(
#    1297     "/chat/completions",
#    1298     body=maybe_transform(
#    1299         {
#    1300             "messages": messages,
#    1301             "model": model,
#    1302             "audio": audio,
#    1303             "frequency_penalty": frequency_penalty,
#    1304             "function_call": function_call,
#    1305             "functions": functions,
#    1306             "logit_bias": logit_bias,
#    1307             "logprobs": logprobs,
#    1308             "max_completion_tokens": max_completion_tokens,
#    1309             "max_tokens": max_tokens,
#    1310             "metadata": metadata,
#    1311             "modalities": modalities,
#    1312             "moderation": moderation,
#    1313             "n": n,
#    1314             "parallel_tool_calls": parallel_tool_calls,
#    1315             "prediction": prediction,
#    1316             "presence_penalty": presence_penalty,
#    1317             "prompt_cache_key": prompt_cache_key,
#    1318             "prompt_cache_options": prompt_cache_options,
#    1319             "prompt_cache_retention": prompt_cache_retention,
#    1320             "reasoning_effort": reasoning_effort,
#    1321             "response_format": response_format,
#    1322             "safety_identifier": safety_identifier,
#    1323             "seed": seed,
#    1324             "service_tier": service_tier,
#    1325             "stop": stop,
#    1326             "store": store,
#    1327             "stream": stream,
#    1328             "stream_options": stream_options,
#    1329             "temperature": temperature,
#    1330             "tool_choice": tool_choice,
#    1331             "tools": tools,
#    1332             "top_logprobs": top_logprobs,
#    1333             "top_p": top_p,
#    1334             "user": user,
#    1335             "verbosity": verbosity,
#    1336             "web_search_options": web_search_options,
#    1337         },
#    1338         completion_create_params.CompletionCreateParamsStreaming
#    1339         if stream
#    1340         else completion_create_params.CompletionCreateParamsNonStreaming,
#    1341     ),
#    1342     options=make_request_options(
#    1343         extra_headers=extra_headers,
#    1344         extra_query=extra_query,
#    1345         extra_body=extra_body,
#    1346         timeout=timeout,
#    1347         security={"bearer_auth": True},
#    1348     ),
#    1349     cast_to=ChatCompletion,
#    1350     stream=stream or False,
#    1351     stream_cls=Stream[ChatCompletionChunk],
#    1352 )
#
# File ~\Desktop\vscode\paul\structured-llm-notebooks\.venv\Lib\site-packages\openai\_base_client.py:1375, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1372 opts = FinalRequestOptions.construct(
#    1373     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1374 )
# -> 1375 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~\Desktop\vscode\paul\structured-llm-notebooks\.venv\Lib\site-packages\openai\_base_client.py:1148, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1147     log.debug("Re-raising status error")
# -> 1148     raise self._make_status_error_from_response(err.response) from None
#    1150 break
#
# AuthenticationError: Error code: 401 - {'error': {'message': 'Incorrect API key provided: sk-your-***********here. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'code': 'invalid_api_key', 'param': None}, 'status': 401}
#
# The above exception was the direct cause of the following exception:
#
# InstructorRetryException                  Traceback (most recent call last)
# Cell In[7], line 31
#      27     try:
#      28         c = get_instructor_client(provider)
#      29         results[provider] = list(stream_extract(c, get_model(provider), text))[-1]
#      30         print(f"{provider.capitalize()} ({get_model(provider)}): {results[provider].model_dump_json()}")
# ---> 31     except ValueError as e:
#      32         print(f"{provider.capitalize()}: skipped — no API key in .env")
#      33
#      34 # Same schema in, same structured objects out — regardless of provider
#
# Cell In[7], line 12, in stream_extract(client, model, text)
#      10 def stream_extract(client, model: str, text: str):
#      11     """Provider-agnostic streaming extraction — same code for everyone."""
# ---> 12     for partial in client.chat.completions.create_partial(
#      13         model=model,
#      14         response_model=Person,
#      15         messages=[{"role": "user", "content": text}],
#
# File ~\Desktop\vscode\paul\structured-llm-notebooks\.venv\Lib\site-packages\instructor\v2\core\client.py:618, in Instructor.create_partial(self, response_model, messages, max_retries, context, strict, hooks, **kwargs)
#     615     combined_hooks = self.hooks + hooks
#     617 response_model = Partial[response_model]  # type: ignore
# --> 618 return self.create_fn(
#     619     messages=messages,
#     620     response_model=response_model,
#     621     max_retries=max_retries,
#     622     context=context,
#     623     strict=strict,
#     624     hooks=combined_hooks,
#     625     **kwargs,
#     626 )
#
# File ~\Desktop\vscode\paul\structured-llm-notebooks\.venv\Lib\site-packages\instructor\v2\core\patch.py:285, in _create_sync_wrapper.<locals>.new_create_sync(response_model, context, max_retries, strict, hooks, token_budget, *args, **kwargs)
#     281                 return cached  # type: ignore[return-value]
#     283 # Use v2 retry logic with registry handlers. Pass an isolated copy of the
#     284 # messages list so reask-handler mutations cannot leak into caller state.
# --> 285 response = retry_sync_v2(
#     286     func=func,
#     287     response_model=response_model,
#     288     provider=provider,
#     289     mode=mode,
#     290     context=context,
#     291     max_retries=max_retries,
#     292     args=args,
#     293     kwargs=isolate_retry_kwargs(new_kwargs),
#     294     strict=strict,
#     295     hooks=hooks,
#     296     token_budget=token_budget,
#     297 )
#     299 if key is not None and isinstance(response, BaseModel):
#     300     from instructor.cache import store_cached_response
#
# File ~\Desktop\vscode\paul\structured-llm-notebooks\.venv\Lib\site-packages\instructor\v2\core\retry.py:434, in retry_sync_v2(func, response_model, provider, mode, context, max_retries, args, kwargs, strict, hooks, token_budget)
#     424     if hooks:
#     425         hooks.emit_completion_last_attempt(
#     426             last_exception,
#     427             **_attempt_metadata(
#    (...)    431             ),
#     432         )
# --> 434     raise InstructorRetryException(
#     435         str(last_exception),
#     436         last_completion=failed_attempts[-1].completion if failed_attempts else None,
#     437         n_attempts=last_attempt_number,
#     438         total_usage=total_usage,
#     439         messages=extract_messages(kwargs),
#     440         create_kwargs=kwargs,
#     441         failed_attempts=failed_attempts,
#     442     ) from last_exception
#     444 # Should never reach here
#     445 logger.error("Unexpected code path in retry_sync_v2")
#
# InstructorRetryException: Error code: 401 - {'error': {'message': 'Incorrect API key provided: sk-your-***********here. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'code': 'invalid_api_key', 'param': None}, 'status': 401}

# %% [markdown]
# ## 7. Latency Benchmark: Streaming vs Non-Streaming UX

# %%
import time


class Summary(BaseModel):
    title: str
    key_points: list[str]


long_text = "Artificial intelligence is transforming..." * 50  # Long text

# Non-streaming: wait for everything
start = time.time()
summary = client.chat.completions.create(
    model=get_model(),
    response_model=Summary,
    messages=[{"role": "user", "content": f"Summarize: {long_text[:500]}"}],
)
non_stream_time = time.time() - start

# Streaming: first field appears immediately
start = time.time()
first_field_time = None
for partial in client.chat.completions.create_partial(
    model=get_model(),
    response_model=Summary,
    messages=[{"role": "user", "content": f"Summarize: {long_text[:500]}"}],
):
    if partial.title and first_field_time is None:
        first_field_time = time.time() - start
        break

print(f"Non-streaming total time: {non_stream_time:.2f}s")
print(f"Streaming — first field visible: {first_field_time:.2f}s")
print(
    f"\n💡 UX improvement: users see data {non_stream_time / first_field_time:.1f}x faster with streaming"
)
# Out:
# Non-streaming total time: 3.61s
# Streaming — first field visible: 2.10s
#
# 💡 UX improvement: users see data 1.7x faster with streaming
