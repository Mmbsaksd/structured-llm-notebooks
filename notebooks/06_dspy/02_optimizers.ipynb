# %% [markdown]
# # DSPy Optimization — BootstrapFewShot vs MIPROv2
#
# **Week 6 | Notebook 2 of 12**
#
# **What you'll learn:**
# - What is compilation? (conceptual walkthrough)
# - Preparing trainset + devset (dspy.Example format)
# - Writing a custom metric function
# - Running BootstrapFewShot — inspect generated few-shot demos
# - Running MIPROv2 — inspect generated instructions
# - Comparing: baseline vs optimized on devset score
# - Saving and reloading the optimized program
#
# **Runtime:** ~45 minutes (API calls during optimization)
#
# **Cost-saving:** Default 10 trials (reduce in .env with DSPY_OPTIMIZER_TRIALS)

# %%
# 💰 COST ESTIMATE
import warnings

from src.cost_tracker import print_cost_warning

warnings.filterwarnings("ignore")

print_cost_warning("06_dspy/02_optimizers.ipynb")
# Out:
# 💰 COST ESTIMATE
# ----------------------------------------
# Notebook:  06_dspy/02_optimizers.ipynb
# Task:      DSPy optimizers (expensive)
# Calls:     ~60
#
# With GPT-4o:       $0.90 USD
# With GPT-4o-mini:  $0.09 USD (10x cheaper)
# With Ollama:       $0.00 USD (free, local)
#
# 💡 TIP: Set USE_SMALL_MODEL=true or USE_OLLAMA=true in .env to save money.
# ----------------------------------------

# %% [markdown]
# ## 1. Setup

# %%
import dspy
from dspy.evaluate import Evaluate
from dspy.teleprompt import BootstrapFewShot, MIPROv2

from src.config import DSPY_OPTIMIZER_TRIALS, get_dspy_lm
from src.datasets import generate_qa_pairs

lm = get_dspy_lm()
dspy.configure(lm=lm)

print("✅ DSPy configured")
print(f"Optimizer trials: {DSPY_OPTIMIZER_TRIALS}")
# Out:
# ✅ DSPy configured
# Optimizer trials: 10

# %% [markdown]
# ## 2. What Is Compilation?

# %%
# DSPy compilation = automatically improving your program
# by generating better instructions and few-shot examples

print("DSPy Compilation Flow:")
print("  1. Define your program (signatures + modules)")
print("  2. Provide training examples")
print("  3. Define a metric (0-1 scoring function)")
print("  4. Run optimizer (BootstrapFewShot / MIPROv2)")
print("  5. Optimized program has better prompts + demos")
print("  6. Evaluate on devset")
print("\n💡 Think of it like a compiler: Python → optimized prompts")
# Out:
# DSPy Compilation Flow:
#   1. Define your program (signatures + modules)
#   2. Provide training examples
#   3. Define a metric (0-1 scoring function)
#   4. Run optimizer (BootstrapFewShot / MIPROv2)
#   5. Optimized program has better prompts + demos
#   6. Evaluate on devset
#
# 💡 Think of it like a compiler: Python → optimized prompts

# %% [markdown]
# ## 3. Preparing Trainset + Devset

# %%
# Convert synthetic data to dspy.Example format
qa_data = generate_qa_pairs(40)

examples = [
    dspy.Example(question=d["question"], answer=d["expected"]).with_inputs("question")
    for d in qa_data
]

# Split: 70% train, 30% dev
split = int(len(examples) * 0.7)
trainset = examples[:split]
devset = examples[split:]

print(f"Trainset: {len(trainset)} examples")
print(f"Devset: {len(devset)} examples")
print("\nSample train example:")
print(f"  Question: {trainset[0].question}")
print(f"  Answer: {trainset[0].answer}")
# Out:
# Trainset: 28 examples
# Devset: 12 examples
#
# Sample train example:
#   Question: What is DSPy?
#   Answer: DSPy is a framework for programming language models.

# %%
examples
# Out:
# [Example({'question': 'What is DSPy?', 'answer': 'DSPy is a framework for programming language models.'}) (input_keys={'question'}),
#  Example({'question': 'What is Vector DB?', 'answer': 'Vector databases store embeddings for similarity search.'}) (input_keys={'question'}),
#  Example({'question': 'What is Fine-tuning?', 'answer': 'Fine-tuning adapts a pre-trained model to a specific task.'}) (input_keys={'question'}),
#  Example({'question': 'What is DSPy?', 'answer': 'DSPy is a framework for programming language models.'}) (input_keys={'question'}),
#  Example({'question': 'What is DSPy?', 'answer': 'DSPy is a framework for programming language models.'}) (input_keys={'question'}),
#  Example({'question': 'What is Attention?', 'answer': 'Attention mechanisms let models focus on relevant tokens.'}) (input_keys={'question'}),
#  Example({'question': 'What is RAG?', 'answer': 'Retrieval-Augmented Generation combines search with LLMs.'}) (input_keys={'question'}),
#  Example({'question': 'What is Fine-tuning?', 'answer': 'Fine-tuning adapts a pre-trained model to a specific task.'}) (input_keys={'question'}),
#  Example({'question': 'What is RAG?', 'answer': 'Retrieval-Augmented Generation combines search with LLMs.'}) (input_keys={'question'}),
#  Example({'question': 'What is Fine-tuning?', 'answer': 'Fine-tuning adapts a pre-trained model to a specific task.'}) (input_keys={'question'}),
#  Example({'question': 'What is Attention?', 'answer': 'Attention mechanisms let models focus on relevant tokens.'}) (input_keys={'question'}),
#  Example({'question': 'What is Transformers?', 'answer': 'Transformers are neural networks based on self-attention.'}) (input_keys={'question'}),
#  Example({'question': 'What is Vector DB?', 'answer': 'Vector databases store embeddings for similarity search.'}) (input_keys={'question'}),
#  Example({'question': 'What is Prompt Engineering?', 'answer': 'Prompt engineering is the art of writing effective prompts.'}) (input_keys={'question'}),
#  Example({'question': 'What is Attention?', 'answer': 'Attention mechanisms let models focus on relevant tokens.'}) (input_keys={'question'}),
#  Example({'question': 'What is Vector DB?', 'answer': 'Vector databases store embeddings for similarity search.'}) (input_keys={'question'}),
#  Example({'question': 'What is Fine-tuning?', 'answer': 'Fine-tuning adapts a pre-trained model to a specific task.'}) (input_keys={'question'}),
#  Example({'question': 'What is DSPy?', 'answer': 'DSPy is a framework for programming language models.'}) (input_keys={'question'}),
#  Example({'question': 'What is Attention?', 'answer': 'Attention mechanisms let models focus on relevant tokens.'}) (input_keys={'question'}),
#  Example({'question': 'What is Chain-of-Thought?', 'answer': 'CoT prompting asks the model to show its reasoning.'}) (input_keys={'question'}),
#  Example({'question': 'What is Vector DB?', 'answer': 'Vector databases store embeddings for similarity search.'}) (input_keys={'question'}),
#  Example({'question': 'What is Transformers?', 'answer': 'Transformers are neural networks based on self-attention.'}) (input_keys={'question'}),
#  Example({'question': 'What is DSPy?', 'answer': 'DSPy is a framework for programming language models.'}) (input_keys={'question'}),
#  Example({'question': 'What is DSPy?', 'answer': 'DSPy is a framework for programming language models.'}) (input_keys={'question'}),
#  Example({'question': 'What is Vector DB?', 'answer': 'Vector databases store embeddings for similarity search.'}) (input_keys={'question'}),
#  Example({'question': 'What is Chain-of-Thought?', 'answer': 'CoT prompting asks the model to show its reasoning.'}) (input_keys={'question'}),
#  Example({'question': 'What is Fine-tuning?', 'answer': 'Fine-tuning adapts a pre-trained model to a specific task.'}) (input_keys={'question'}),
#  Example({'question': 'What is DSPy?', 'answer': 'DSPy is a framework for programming language models.'}) (input_keys={'question'}),
#  Example({'question': 'What is Fine-tuning?', 'answer': 'Fine-tuning adapts a pre-trained model to a specific task.'}) (input_keys={'question'}),
#  Example({'question': 'What is DSPy?', 'answer': 'DSPy is a framework for programming language models.'}) (input_keys={'question'}),
#  Example({'question': 'What is DSPy?', 'answer': 'DSPy is a framework for programming language models.'}) (input_keys={'question'}),
#  Example({'question': 'What is Vector DB?', 'answer': 'Vector databases store embeddings for similarity search.'}) (input_keys={'question'}),
#  Example({'question': 'What is Chain-of-Thought?', 'answer': 'CoT prompting asks the model to show its reasoning.'}) (input_keys={'question'}),
#  Example({'question': 'What is Chain-of-Thought?', 'answer': 'CoT prompting asks the model to show its reasoning.'}) (input_keys={'question'}),
#  Example({'question': 'What is Fine-tuning?', 'answer': 'Fine-tuning adapts a pre-trained model to a specific task.'}) (input_keys={'question'}),
#  Example({'question': 'What is Vector DB?', 'answer': 'Vector databases store embeddings for similarity search.'}) (input_keys={'question'}),
#  Example({'question': 'What is DSPy?', 'answer': 'DSPy is a framework for programming language models.'}) (input_keys={'question'}),
#  Example({'question': 'What is Prompt Engineering?', 'answer': 'Prompt engineering is the art of writing effective prompts.'}) (input_keys={'question'}),
#  Example({'question': 'What is Fine-tuning?', 'answer': 'Fine-tuning adapts a pre-trained model to a specific task.'}) (input_keys={'question'}),
#  Example({'question': 'What is Transformers?', 'answer': 'Transformers are neural networks based on self-attention.'}) (input_keys={'question'})]

# %% [markdown]
# ## 4. Writing a Custom Metric

# %%
def answer_metric(example, prediction, trace=None):
    """Check if predicted answer covers the expected answer's content.

    Word-overlap ratio (expected words found in prediction). A plain substring
    check scores 0 on paraphrases, which leaves optimizers with nothing to
    bootstrap from.
    """
    expected = set(example.answer.lower().split())
    predicted = set(prediction.answer.lower().split())
    if not expected:
        return 0.0
    return 1.0 if len(expected & predicted) / len(expected) >= 0.3 else 0.0


# Test the metric
class TestEx(dspy.Example):
    pass


ex = dspy.Example(question="What is RAG?", answer="It Mean Retrieval Augmented Generation").with_inputs(
    "question"
)
pred = dspy.Prediction(answer="Retrieval")
print(f"Metric score: {answer_metric(ex, pred)}")
# Out:
# Metric score: 0.0

# %% [markdown]
# ## 5. Baseline Program

# %%
class QA(dspy.Signature):
    """Answer questions with short factual responses."""

    question: str = dspy.InputField()
    answer: str = dspy.OutputField()


class SimpleQA(dspy.Module):
    def __init__(self):
        super().__init__()
        self.generate = dspy.ChainOfThought(QA)

    def forward(self, question):
        return self.generate(question=question)


baseline = SimpleQA()

# Evaluate baseline
evaluator = Evaluate(devset=devset, metric=answer_metric, num_threads=4, display_progress=True)
baseline_score = evaluator(baseline).score
print(f"\nBaseline score: {baseline_score:.2f}")
# Out:
# Average Metric: 10.00 / 12 (83.3%): 100%|██████████| 12/12 [00:08<00:00,  1.36it/s]
# 2026/09/23 21:08:54 INFO dspy.evaluate.evaluate: Average Metric: 10.0 / 12 (83.3%)
# Baseline score: 83.33

# %% [markdown]
# ## 6. BootstrapFewShot — Quick Baseline Optimizer

# %%
# BootstrapFewShot: generates few-shot demos by running the program
teleprompter = BootstrapFewShot(metric=answer_metric, max_bootstrapped_demos=4)

optimized_bootstrap = teleprompter.compile(SimpleQA(), trainset=trainset)

# Evaluate optimized
bootstrap_score = evaluator(optimized_bootstrap).score
print(f"\nBootstrapFewShot score: {bootstrap_score:.2f}")
print(f"Improvement: {bootstrap_score - baseline_score:+.2f}")
# Out:
#  18%|█▊        | 5/28 [00:00<00:01, 15.11it/s]
# Bootstrapped 4 full traces after 5 examples for up to 1 rounds, amounting to 5 attempts.
# Average Metric: 10.00 / 12 (83.3%): 100%|██████████| 12/12 [00:00<00:00, 81.31it/s]
# 2026/09/23 21:08:54 INFO dspy.evaluate.evaluate: Average Metric: 10.0 / 12 (83.3%)
# BootstrapFewShot score: 83.33
# Improvement: +0.00

# %%
#optimized_bootstrap.save("optimized_bootstrap1.json")
optimized_bootstrap(question="What is RAG?")
dspy.inspect_history(n=1)
# Out:
# [2026-09-23T21:08:54.959744]
#
# System message:
#
# Your input fields are:
# 1. `question` (str):
# Your output fields are:
# 1. `reasoning` (str):
# 2. `answer` (str):
# All interactions will be structured in the following way, with the appropriate values filled in.
#
# [[ ## question ## ]]
# {question}
#
# [[ ## reasoning ## ]]
# {reasoning}
#
# [[ ## answer ## ]]
# {answer}
#
# [[ ## completed ## ]]
# In adhering to this structure, your objective is:
#         Answer questions with short factual responses.
#
#
# User message:
#
# This is an example of the task, though some input or output fields are not supplied.
#
# [[ ## question ## ]]
# What is Fine-tuning?
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# Not supplied for this particular example.
#
# [[ ## answer ## ]]
# Fine-tuning adapts a pre-trained model to a specific task.
#
# [[ ## completed ## ]]
#
#
# User message:
#
# This is an example of the task, though some input or output fields are not supplied.
#
# [[ ## question ## ]]
# What is DSPy?
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# Not supplied for this particular example.
#
# [[ ## answer ## ]]
# DSPy is a framework for programming language models.
#
# [[ ## completed ## ]]
#
#
# User message:
#
# This is an example of the task, though some input or output fields are not supplied.
#
# [[ ## question ## ]]
# What is Vector DB?
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# Not supplied for this particular example.
#
# [[ ## answer ## ]]
# Vector databases store embeddings for similarity search.
#
# [[ ## completed ## ]]
#
#
# User message:
#
# This is an example of the task, though some input or output fields are not supplied.
#
# [[ ## question ## ]]
# What is Attention?
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# Not supplied for this particular example.
#
# [[ ## answer ## ]]
# Attention mechanisms let models focus on relevant tokens.
#
# [[ ## completed ## ]]
#
#
# User message:
#
# This is an example of the task, though some input or output fields are not supplied.
#
# [[ ## question ## ]]
# What is Prompt Engineering?
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# Not supplied for this particular example.
#
# [[ ## answer ## ]]
# Prompt engineering is the art of writing effective prompts.
#
# [[ ## completed ## ]]
#
#
# User message:
#
# This is an example of the task, though some input or output fields are not supplied.
#
# [[ ## question ## ]]
# What is DSPy?
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# Not supplied for this particular example.
#
# [[ ## answer ## ]]
# DSPy is a framework for programming language models.
#
# [[ ## completed ## ]]
#
#
# User message:
#
# This is an example of the task, though some input or output fields are not supplied.
#
# [[ ## question ## ]]
# What is Fine-tuning?
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# Not supplied for this particular example.
#
# [[ ## answer ## ]]
# Fine-tuning adapts a pre-trained model to a specific task.
#
# [[ ## completed ## ]]
#
#
# User message:
#
# This is an example of the task, though some input or output fields are not supplied.
#
# [[ ## question ## ]]
# What is RAG?
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# Not supplied for this particular example.
#
# [[ ## answer ## ]]
# Retrieval-Augmented Generation combines search with LLMs.
#
# [[ ## completed ## ]]
#
#
# User message:
#
# This is an example of the task, though some input or output fields are not supplied.
#
# [[ ## question ## ]]
# What is Chain-of-Thought?
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# Not supplied for this particular example.
#
# [[ ## answer ## ]]
# CoT prompting asks the model to show its reasoning.
#
# [[ ## completed ## ]]
#
#
# User message:
#
# This is an example of the task, though some input or output fields are not supplied.
#
# [[ ## question ## ]]
# What is Vector DB?
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# Not supplied for this particular example.
#
# [[ ## answer ## ]]
# Vector databases store embeddings for similarity search.
#
# [[ ## completed ## ]]
#
#
# User message:
#
# This is an example of the task, though some input or output fields are not supplied.
#
# [[ ## question ## ]]
# What is Vector DB?
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# Not supplied for this particular example.
#
# [[ ## answer ## ]]
# Vector databases store embeddings for similarity search.
#
# [[ ## completed ## ]]
#
#
# User message:
#
# This is an example of the task, though some input or output fields are not supplied.
#
# [[ ## question ## ]]
# What is Transformers?
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# Not supplied for this particular example.
#
# [[ ## answer ## ]]
# Transformers are neural networks based on self-attention.
#
# [[ ## completed ## ]]
#
#
# User message:
#
# [[ ## question ## ]]
# What is DSPy?
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# DSPy is a framework designed for creating and deploying data science pipelines efficiently. It helps streamline the process of building machine learning models by providing a structured approach to data handling and model development.
#
# [[ ## answer ## ]]
# DSPy is a framework for building and deploying data science pipelines.
#
# [[ ## completed ## ]]
#
#
# User message:
#
# [[ ## question ## ]]
# What is Fine-tuning?
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# Fine-tuning is the process of taking a pre-trained model and training it further on a specific dataset to improve its performance on a particular task.
#
# [[ ## answer ## ]]
# Fine-tuning adjusts a pre-trained model on a specific task to enhance its performance.
#
# [[ ## completed ## ]]
#
#
# User message:
#
# [[ ## question ## ]]
# What is DSPy?
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# DSPy is a framework designed for creating and deploying data science pipelines efficiently. It helps streamline the process of building machine learning models by providing a structured approach to data handling and model development.
#
# [[ ## answer ## ]]
# DSPy is a framework for building and deploying data science pipelines.
#
# [[ ## completed ## ]]
#
#
# User message:
#
# [[ ## question ## ]]
# What is DSPy?
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# DSPy is a framework designed for creating and deploying data science pipelines efficiently. It helps streamline the process of building machine learning models by providing a structured approach to data handling and model development.
#
# [[ ## answer ## ]]
# DSPy is a framework for building and deploying data science pipelines.
#
# [[ ## completed ## ]]
#
#
# User message:
#
# [[ ## question ## ]]
# What is RAG?
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## answer ## ]]`, and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Response:
#
# [[ ## reasoning ## ]]
# RAG stands for Retrieval-Augmented Generation, which is a model that combines the capabilities of information retrieval and text generation. It retrieves relevant documents or information from a database and uses it to generate more accurate and contextually relevant responses. This approach leverages both retrieval techniques and generative models to improve the overall performance in natural language processing tasks.
#
# [[ ## answer ## ]]
# RAG (Retrieval-Augmented Generation) combines information retrieval with text generation for improved accuracy.
#
# [[ ## completed ## ]]

# %% [markdown]
# ## 7. MIPROv2 — Bayesian Optimization

# %%
# MIPROv2: Bayesian optimization of instructions + demos
# More expensive but generally better results

mipro = MIPROv2(
    metric=answer_metric,
    auto=None,  # dspy 3.3: opt out of auto budget to set candidates/trials manually
    num_candidates=5,  # Reduced for cost
    init_temperature=1.0,
)

optimized_mipro = mipro.compile(
    SimpleQA(),
    trainset=trainset,
    num_trials=DSPY_OPTIMIZER_TRIALS,  # Configurable via .env
    valset=devset,
    minibatch=False,  # Small valset (12) — default minibatch size is 35
)

# Evaluate optimized
mipro_score = evaluator(optimized_mipro).score
print(f"\nMIPROv2 score: {mipro_score:.2f}")
print(f"Improvement over baseline: {mipro_score - baseline_score:+.2f}")
print(f"Improvement over Bootstrap: {mipro_score - bootstrap_score:+.2f}")
# Out:
# 2026/09/23 21:08:54 INFO dspy.teleprompt.mipro_optimizer_v2:
# ==> STEP 1: BOOTSTRAP FEWSHOT EXAMPLES <==
# 2026/09/23 21:08:54 INFO dspy.teleprompt.mipro_optimizer_v2: These will be used as few-shot example candidates for our program and for creating instructions.
#
# 2026/09/23 21:08:54 INFO dspy.teleprompt.mipro_optimizer_v2: Bootstrapping N=5 sets of demonstrations...
# Bootstrapping set 1/5
# Bootstrapping set 2/5
# Bootstrapping set 3/5
#  18%|█▊        | 5/28 [00:00<00:01, 15.09it/s]
# Bootstrapped 4 full traces after 5 examples for up to 1 rounds, amounting to 5 attempts.
# Bootstrapping set 4/5
#   4%|▎         | 1/28 [00:00<00:01, 15.58it/s]
# Bootstrapped 1 full traces after 1 examples for up to 1 rounds, amounting to 1 attempts.
# Bootstrapping set 5/5
#   4%|▎         | 1/28 [00:00<00:01, 14.70it/s]
# 2026/09/23 21:08:55 INFO dspy.teleprompt.mipro_optimizer_v2:
# ==> STEP 2: PROPOSE INSTRUCTION CANDIDATES <==
# 2026/09/23 21:08:55 INFO dspy.teleprompt.mipro_optimizer_v2: We will use the few-shot examples from the previous step, a generated dataset summary, a summary of the program code, and a randomly selected prompting tip to propose instructions.
# Bootstrapped 1 full traces after 1 examples for up to 1 rounds, amounting to 1 attempts.
# 2026/09/23 21:08:55 INFO dspy.teleprompt.mipro_optimizer_v2:
# Proposing N=5 instructions...
#
# 2026/09/23 21:08:55 WARNING dspy.predict.predict: Input contains fields not in signature. These fields will be ignored: ['max_depth']. Expected fields: ['program_code', 'program_example', 'program_description', 'module'].
# 2026/09/23 21:08:55 WARNING dspy.predict.predict: Input contains fields not in signature. These fields will be ignored: ['previous_instructions']. Expected fields: ['dataset_description', 'program_code', 'program_description', 'module', 'module_description', 'task_demos', 'basic_instruction', 'tip'].
# 2026/09/23 21:08:55 WARNING dspy.predict.predict: Input contains fields not in signature. These fields will be ignored: ['max_depth']. Expected fields: ['program_code', 'program_example', 'program_description', 'module'].
# 2026/09/23 21:08:55 WARNING dspy.predict.predict: Input contains fields not in signature. These fields will be ignored: ['tip', 'previous_instructions']. Expected fields: ['dataset_description', 'program_code', 'program_description', 'module', 'module_description', 'task_demos', 'basic_instruction'].
# 2026/09/23 21:08:55 WARNING dspy.predict.predict: Input contains fields not in signature. These fields will be ignored: ['max_depth']. Expected fields: ['program_code', 'program_example', 'program_description', 'module'].
# 2026/09/23 21:08:55 WARNING dspy.predict.predict: Input contains fields not in signature. These fields will be ignored: ['previous_instructions']. Expected fields: ['dataset_description', 'program_code', 'program_description', 'module', 'module_description', 'task_demos', 'basic_instruction', 'tip'].
# 2026/09/23 21:08:55 WARNING dspy.predict.predict: Input contains fields not in signature. These fields will be ignored: ['max_depth']. Expected fields: ['program_code', 'program_example', 'program_description', 'module'].
# 2026/09/23 21:08:55 WARNING dspy.predict.predict: Input contains fields not in signature. These fields will be ignored: ['previous_instructions']. Expected fields: ['dataset_description', 'program_code', 'program_description', 'module', 'module_description', 'task_demos', 'basic_instruction', 'tip'].
# 2026/09/23 21:08:55 WARNING dspy.predict.predict: Input contains fields not in signature. These fields will be ignored: ['max_depth']. Expected fields: ['program_code', 'program_example', 'program_description', 'module'].
# 2026/09/23 21:08:56 WARNING dspy.predict.predict: Input contains fields not in signature. These fields will be ignored: ['tip', 'previous_instructions']. Expected fields: ['dataset_description', 'program_code', 'program_description', 'module', 'module_description', 'task_demos', 'basic_instruction'].
# 2026/09/23 21:08:56 INFO dspy.teleprompt.mipro_optimizer_v2: Proposed Instructions for Predictor 0:
#
# 2026/09/23 21:08:56 INFO dspy.teleprompt.mipro_optimizer_v2: 0: Answer questions with short factual responses.
#
# 2026/09/23 21:08:56 INFO dspy.teleprompt.mipro_optimizer_v2: 1: Generate a well-structured answer to the user's question that includes a concise factual response and a reasoning explanation that clarifies the answer. Ensure that both components are clearly labeled as 'Reasoning:' and 'Answer:', respectively.
#
# 2026/09/23 21:08:56 INFO dspy.teleprompt.mipro_optimizer_v2: 2: In a high-stakes scenario where clarity and accuracy are crucial, you must act as an expert in machine learning and AI. When presented with a question, provide a short factual answer, accompanied by clear reasoning that explains the basis for your response. Ensure that your responses are concise yet informative, as they will be used to guide learners seeking to enhance their understanding of AI concepts.
#
# 2026/09/23 21:08:56 INFO dspy.teleprompt.mipro_optimizer_v2: 3: Provide concise and accurate answers to questions, along with a brief reasoning for each response, ensuring clarity and logical coherence in your outputs.
#
# 2026/09/23 21:08:56 INFO dspy.teleprompt.mipro_optimizer_v2: 4: Provide a clear and concise answer to the question, including a logical reasoning statement that supports your response. Ensure that the reasoning helps contextualize the answer, making it easier for the user to understand the concept being queried.
#
# 2026/09/23 21:08:56 INFO dspy.teleprompt.mipro_optimizer_v2:
#
# 2026/09/23 21:08:57 INFO dspy.teleprompt.mipro_optimizer_v2: ==> STEP 3: FINDING OPTIMAL PROMPT PARAMETERS <==
# 2026/09/23 21:08:57 INFO dspy.teleprompt.mipro_optimizer_v2: We will evaluate the program over a series of trials with different combinations of instructions and few-shot examples to find the optimal combination using Bayesian Optimization.
#
# 2026/09/23 21:08:57 INFO dspy.teleprompt.mipro_optimizer_v2: == Trial 1 / 10 - Full Evaluation of Default Program ==
# Average Metric: 10.00 / 12 (83.3%): 100%|██████████| 12/12 [00:00<00:00, 86.79it/s]
# 2026/09/23 21:08:57 INFO dspy.evaluate.evaluate: Average Metric: 10.0 / 12 (83.3%)
# 2026/09/23 21:08:57 INFO dspy.teleprompt.mipro_optimizer_v2: Default program score: 83.33
# 2026/09/23 21:08:58 INFO dspy.teleprompt.mipro_optimizer_v2: ===== Trial 2 / 10 =====
# Average Metric: 8.00 / 12 (66.7%): 100%|██████████| 12/12 [00:10<00:00,  1.19it/s]
# 2026/09/23 21:09:08 INFO dspy.evaluate.evaluate: Average Metric: 8.0 / 12 (66.7%)
# 2026/09/23 21:09:08 INFO dspy.teleprompt.mipro_optimizer_v2: Score: 66.67 with parameters ['Predictor 0: Instruction 1', 'Predictor 0: Few-Shot Set 1'].
# 2026/09/23 21:09:08 INFO dspy.teleprompt.mipro_optimizer_v2: Scores so far: [83.33, 66.67]
# 2026/09/23 21:09:08 INFO dspy.teleprompt.mipro_optimizer_v2: Best score so far: 83.33
# 2026/09/23 21:09:08 INFO dspy.teleprompt.mipro_optimizer_v2: ========================
#
#
# 2026/09/23 21:09:08 INFO dspy.teleprompt.mipro_optimizer_v2: ===== Trial 3 / 10 =====
# Average Metric: 10.00 / 12 (83.3%): 100%|██████████| 12/12 [00:04<00:00,  2.59it/s]
# 2026/09/23 21:09:13 INFO dspy.evaluate.evaluate: Average Metric: 10.0 / 12 (83.3%)
# 2026/09/23 21:09:13 INFO dspy.teleprompt.mipro_optimizer_v2: Score: 83.33 with parameters ['Predictor 0: Instruction 2', 'Predictor 0: Few-Shot Set 1'].
# 2026/09/23 21:09:13 INFO dspy.teleprompt.mipro_optimizer_v2: Scores so far: [83.33, 66.67, 83.33]
# 2026/09/23 21:09:13 INFO dspy.teleprompt.mipro_optimizer_v2: Best score so far: 83.33
# 2026/09/23 21:09:13 INFO dspy.teleprompt.mipro_optimizer_v2: ========================
#
#
# 2026/09/23 21:09:13 INFO dspy.teleprompt.mipro_optimizer_v2: ===== Trial 4 / 10 =====
# Average Metric: 10.00 / 12 (83.3%): 100%|██████████| 12/12 [00:11<00:00,  1.00it/s]
# 2026/09/23 21:09:25 INFO dspy.evaluate.evaluate: Average Metric: 10.0 / 12 (83.3%)
# 2026/09/23 21:09:25 INFO dspy.teleprompt.mipro_optimizer_v2: Score: 83.33 with parameters ['Predictor 0: Instruction 4', 'Predictor 0: Few-Shot Set 1'].
# 2026/09/23 21:09:25 INFO dspy.teleprompt.mipro_optimizer_v2: Scores so far: [83.33, 66.67, 83.33, 83.33]
# 2026/09/23 21:09:25 INFO dspy.teleprompt.mipro_optimizer_v2: Best score so far: 83.33
# 2026/09/23 21:09:25 INFO dspy.teleprompt.mipro_optimizer_v2: ========================
#
#
# 2026/09/23 21:09:25 INFO dspy.teleprompt.mipro_optimizer_v2: ===== Trial 5 / 10 =====
# Average Metric: 10.00 / 12 (83.3%): 100%|██████████| 12/12 [00:00<00:00, 79.40it/s]
# 2026/09/23 21:09:25 INFO dspy.evaluate.evaluate: Average Metric: 10.0 / 12 (83.3%)
# 2026/09/23 21:09:25 INFO dspy.teleprompt.mipro_optimizer_v2: Score: 83.33 with parameters ['Predictor 0: Instruction 2', 'Predictor 0: Few-Shot Set 1'].
# 2026/09/23 21:09:25 INFO dspy.teleprompt.mipro_optimizer_v2: Scores so far: [83.33, 66.67, 83.33, 83.33, 83.33]
# 2026/09/23 21:09:25 INFO dspy.teleprompt.mipro_optimizer_v2: Best score so far: 83.33
# 2026/09/23 21:09:25 INFO dspy.teleprompt.mipro_optimizer_v2: ========================
#
#
# 2026/09/23 21:09:25 INFO dspy.teleprompt.mipro_optimizer_v2: ===== Trial 6 / 10 =====
# Average Metric: 9.00 / 12 (75.0%): 100%|██████████| 12/12 [00:10<00:00,  1.13it/s]
# 2026/09/23 21:09:36 INFO dspy.evaluate.evaluate: Average Metric: 9.0 / 12 (75.0%)
# 2026/09/23 21:09:36 INFO dspy.teleprompt.mipro_optimizer_v2: Score: 75.0 with parameters ['Predictor 0: Instruction 4', 'Predictor 0: Few-Shot Set 3'].
# 2026/09/23 21:09:36 INFO dspy.teleprompt.mipro_optimizer_v2: Scores so far: [83.33, 66.67, 83.33, 83.33, 83.33, 75.0]
# 2026/09/23 21:09:36 INFO dspy.teleprompt.mipro_optimizer_v2: Best score so far: 83.33
# 2026/09/23 21:09:36 INFO dspy.teleprompt.mipro_optimizer_v2: ========================
#
#
# 2026/09/23 21:09:36 INFO dspy.teleprompt.mipro_optimizer_v2: ===== Trial 7 / 10 =====
# Average Metric: 10.00 / 12 (83.3%): 100%|██████████| 12/12 [00:05<00:00,  2.06it/s]
# 2026/09/23 21:09:42 INFO dspy.evaluate.evaluate: Average Metric: 10.0 / 12 (83.3%)
# 2026/09/23 21:09:42 INFO dspy.teleprompt.mipro_optimizer_v2: Score: 83.33 with parameters ['Predictor 0: Instruction 0', 'Predictor 0: Few-Shot Set 1'].
# 2026/09/23 21:09:42 INFO dspy.teleprompt.mipro_optimizer_v2: Scores so far: [83.33, 66.67, 83.33, 83.33, 83.33, 75.0, 83.33]
# 2026/09/23 21:09:42 INFO dspy.teleprompt.mipro_optimizer_v2: Best score so far: 83.33
# 2026/09/23 21:09:42 INFO dspy.teleprompt.mipro_optimizer_v2: ========================
#
#
# 2026/09/23 21:09:42 INFO dspy.teleprompt.mipro_optimizer_v2: ===== Trial 8 / 10 =====
# Average Metric: 10.00 / 12 (83.3%): 100%|██████████| 12/12 [00:04<00:00,  2.54it/s]
# 2026/09/23 21:09:46 INFO dspy.evaluate.evaluate: Average Metric: 10.0 / 12 (83.3%)
# 2026/09/23 21:09:46 INFO dspy.teleprompt.mipro_optimizer_v2: Score: 83.33 with parameters ['Predictor 0: Instruction 4', 'Predictor 0: Few-Shot Set 4'].
# 2026/09/23 21:09:46 INFO dspy.teleprompt.mipro_optimizer_v2: Scores so far: [83.33, 66.67, 83.33, 83.33, 83.33, 75.0, 83.33, 83.33]
# 2026/09/23 21:09:46 INFO dspy.teleprompt.mipro_optimizer_v2: Best score so far: 83.33
# 2026/09/23 21:09:46 INFO dspy.teleprompt.mipro_optimizer_v2: ========================
#
#
# 2026/09/23 21:09:46 INFO dspy.teleprompt.mipro_optimizer_v2: ===== Trial 9 / 10 =====
# Average Metric: 10.00 / 12 (83.3%): 100%|██████████| 12/12 [00:00<00:00, 105.18it/s]
# 2026/09/23 21:09:47 INFO dspy.evaluate.evaluate: Average Metric: 10.0 / 12 (83.3%)
# 2026/09/23 21:09:47 INFO dspy.teleprompt.mipro_optimizer_v2: Score: 83.33 with parameters ['Predictor 0: Instruction 0', 'Predictor 0: Few-Shot Set 0'].
# 2026/09/23 21:09:47 INFO dspy.teleprompt.mipro_optimizer_v2: Scores so far: [83.33, 66.67, 83.33, 83.33, 83.33, 75.0, 83.33, 83.33, 83.33]
# 2026/09/23 21:09:47 INFO dspy.teleprompt.mipro_optimizer_v2: Best score so far: 83.33
# 2026/09/23 21:09:47 INFO dspy.teleprompt.mipro_optimizer_v2: ========================
#
#
# 2026/09/23 21:09:47 INFO dspy.teleprompt.mipro_optimizer_v2: ===== Trial 10 / 10 =====
# Average Metric: 10.00 / 12 (83.3%): 100%|██████████| 12/12 [00:03<00:00,  3.42it/s]
# 2026/09/23 21:09:50 INFO dspy.evaluate.evaluate: Average Metric: 10.0 / 12 (83.3%)
# 2026/09/23 21:09:50 INFO dspy.teleprompt.mipro_optimizer_v2: Score: 83.33 with parameters ['Predictor 0: Instruction 3', 'Predictor 0: Few-Shot Set 1'].
# 2026/09/23 21:09:50 INFO dspy.teleprompt.mipro_optimizer_v2: Scores so far: [83.33, 66.67, 83.33, 83.33, 83.33, 75.0, 83.33, 83.33, 83.33, 83.33]
# 2026/09/23 21:09:50 INFO dspy.teleprompt.mipro_optimizer_v2: Best score so far: 83.33
# 2026/09/23 21:09:50 INFO dspy.teleprompt.mipro_optimizer_v2: =========================
#
#
# 2026/09/23 21:09:50 INFO dspy.teleprompt.mipro_optimizer_v2: ===== Trial 11 / 10 =====
# Average Metric: 9.00 / 12 (75.0%): 100%|██████████| 12/12 [00:06<00:00,  1.91it/s]
# 2026/09/23 21:09:56 INFO dspy.evaluate.evaluate: Average Metric: 9.0 / 12 (75.0%)
# 2026/09/23 21:09:56 INFO dspy.teleprompt.mipro_optimizer_v2: Score: 75.0 with parameters ['Predictor 0: Instruction 0', 'Predictor 0: Few-Shot Set 2'].
# 2026/09/23 21:09:56 INFO dspy.teleprompt.mipro_optimizer_v2: Scores so far: [83.33, 66.67, 83.33, 83.33, 83.33, 75.0, 83.33, 83.33, 83.33, 83.33, 75.0]
# 2026/09/23 21:09:56 INFO dspy.teleprompt.mipro_optimizer_v2: Best score so far: 83.33
# 2026/09/23 21:09:56 INFO dspy.teleprompt.mipro_optimizer_v2: =========================
#
#
# 2026/09/23 21:09:56 INFO dspy.teleprompt.mipro_optimizer_v2: Returning best identified program with score 83.33!
# Average Metric: 10.00 / 12 (83.3%): 100%|██████████| 12/12 [00:00<00:00, 54.34it/s]
# 2026/09/23 21:09:57 INFO dspy.evaluate.evaluate: Average Metric: 10.0 / 12 (83.3%)
# MIPROv2 score: 83.33
# Improvement over baseline: +0.00
# Improvement over Bootstrap: +0.00

# %% [markdown]
# ## 8. Inspecting What the Optimizers Changed
#
# Optimizers return a *compiled program* — but what actually changed inside it? For both
# optimizers, everything attaches to the inner `Predict` of the `ChainOfThought`
# (`optimized_*.generate.predict`):
#
# - **`.demos`** — the few-shot examples copied into every prompt
# - **`.signature.instructions`** — the task text the model reads
#
# The two optimizers differ in *which* of these they touch: BootstrapFewShot only adds
# demos; MIPROv2 rewrites **both** instructions and demos.

# %%
# MIPROv2: Bayesian optimization of instructions + demos
# More expensive but generally better results

mipro = MIPROv2(
    metric=answer_metric,
    auto=None,  # dspy 3.3: opt out of auto budget to set candidates/trials manually
    num_candidates=5,  # Reduced for cost
    init_temperature=1.0,
)

optimized_mipro = mipro.compile(
    SimpleQA(),
    trainset=trainset,
    num_trials=DSPY_OPTIMIZER_TRIALS,  # Configurable via .env
    valset=devset,
    minibatch=False,  # Small valset (12) — default minibatch size is 35
)

# Evaluate optimized
mipro_score = evaluator(optimized_mipro).score
print(f"\nMIPROv2 score: {mipro_score:.2f}")
print(f"Improvement over baseline: {mipro_score - baseline_score:+.2f}")
print(f"Improvement over Bootstrap: {mipro_score - bootstrap_score:+.2f}")
# Out:
# 2026/09/23 21:09:57 INFO dspy.teleprompt.mipro_optimizer_v2:
# ==> STEP 1: BOOTSTRAP FEWSHOT EXAMPLES <==
# 2026/09/23 21:09:57 INFO dspy.teleprompt.mipro_optimizer_v2: These will be used as few-shot example candidates for our program and for creating instructions.
#
# 2026/09/23 21:09:57 INFO dspy.teleprompt.mipro_optimizer_v2: Bootstrapping N=5 sets of demonstrations...
# Bootstrapping set 1/5
# Bootstrapping set 2/5
# Bootstrapping set 3/5
#  18%|█▊        | 5/28 [00:00<00:02, 10.07it/s]
# Bootstrapped 4 full traces after 5 examples for up to 1 rounds, amounting to 5 attempts.
# Bootstrapping set 4/5
#   4%|▎         | 1/28 [00:00<00:02, 12.64it/s]
# Bootstrapped 1 full traces after 1 examples for up to 1 rounds, amounting to 1 attempts.
# Bootstrapping set 5/5
#   4%|▎         | 1/28 [00:00<00:01, 13.74it/s]
# 2026/09/23 21:09:57 INFO dspy.teleprompt.mipro_optimizer_v2:
# ==> STEP 2: PROPOSE INSTRUCTION CANDIDATES <==
# 2026/09/23 21:09:57 INFO dspy.teleprompt.mipro_optimizer_v2: We will use the few-shot examples from the previous step, a generated dataset summary, a summary of the program code, and a randomly selected prompting tip to propose instructions.
# Bootstrapped 1 full traces after 1 examples for up to 1 rounds, amounting to 1 attempts.
# 2026/09/23 21:09:57 INFO dspy.teleprompt.mipro_optimizer_v2:
# Proposing N=5 instructions...
#
# 2026/09/23 21:09:58 WARNING dspy.predict.predict: Input contains fields not in signature. These fields will be ignored: ['max_depth']. Expected fields: ['program_code', 'program_example', 'program_description', 'module'].
# 2026/09/23 21:09:58 WARNING dspy.predict.predict: Input contains fields not in signature. These fields will be ignored: ['previous_instructions']. Expected fields: ['dataset_description', 'program_code', 'program_description', 'module', 'module_description', 'task_demos', 'basic_instruction', 'tip'].
# 2026/09/23 21:09:58 WARNING dspy.predict.predict: Input contains fields not in signature. These fields will be ignored: ['max_depth']. Expected fields: ['program_code', 'program_example', 'program_description', 'module'].
# 2026/09/23 21:09:58 WARNING dspy.predict.predict: Input contains fields not in signature. These fields will be ignored: ['tip', 'previous_instructions']. Expected fields: ['dataset_description', 'program_code', 'program_description', 'module', 'module_description', 'task_demos', 'basic_instruction'].
# 2026/09/23 21:09:58 WARNING dspy.predict.predict: Input contains fields not in signature. These fields will be ignored: ['max_depth']. Expected fields: ['program_code', 'program_example', 'program_description', 'module'].
# 2026/09/23 21:09:58 WARNING dspy.predict.predict: Input contains fields not in signature. These fields will be ignored: ['previous_instructions']. Expected fields: ['dataset_description', 'program_code', 'program_description', 'module', 'module_description', 'task_demos', 'basic_instruction', 'tip'].
# 2026/09/23 21:09:58 WARNING dspy.predict.predict: Input contains fields not in signature. These fields will be ignored: ['max_depth']. Expected fields: ['program_code', 'program_example', 'program_description', 'module'].
# 2026/09/23 21:09:58 WARNING dspy.predict.predict: Input contains fields not in signature. These fields will be ignored: ['previous_instructions']. Expected fields: ['dataset_description', 'program_code', 'program_description', 'module', 'module_description', 'task_demos', 'basic_instruction', 'tip'].
# 2026/09/23 21:09:58 WARNING dspy.predict.predict: Input contains fields not in signature. These fields will be ignored: ['max_depth']. Expected fields: ['program_code', 'program_example', 'program_description', 'module'].
# 2026/09/23 21:09:58 WARNING dspy.predict.predict: Input contains fields not in signature. These fields will be ignored: ['tip', 'previous_instructions']. Expected fields: ['dataset_description', 'program_code', 'program_description', 'module', 'module_description', 'task_demos', 'basic_instruction'].
# 2026/09/23 21:09:58 INFO dspy.teleprompt.mipro_optimizer_v2: Proposed Instructions for Predictor 0:
#
# 2026/09/23 21:09:58 INFO dspy.teleprompt.mipro_optimizer_v2: 0: Answer questions with short factual responses.
#
# 2026/09/23 21:09:58 INFO dspy.teleprompt.mipro_optimizer_v2: 1: Generate a well-structured answer to the user's question that includes a concise factual response and a reasoning explanation that clarifies the answer. Ensure that both components are clearly labeled as 'Reasoning:' and 'Answer:', respectively.
#
# 2026/09/23 21:09:58 INFO dspy.teleprompt.mipro_optimizer_v2: 2: In a high-stakes scenario where clarity and accuracy are crucial, you must act as an expert in machine learning and AI. When presented with a question, provide a short factual answer, accompanied by clear reasoning that explains the basis for your response. Ensure that your responses are concise yet informative, as they will be used to guide learners seeking to enhance their understanding of AI concepts.
#
# 2026/09/23 21:09:58 INFO dspy.teleprompt.mipro_optimizer_v2: 3: Provide concise and accurate answers to questions, along with a brief reasoning for each response, ensuring clarity and logical coherence in your outputs.
#
# 2026/09/23 21:09:58 INFO dspy.teleprompt.mipro_optimizer_v2: 4: Provide a clear and concise answer to the question, including a logical reasoning statement that supports your response. Ensure that the reasoning helps contextualize the answer, making it easier for the user to understand the concept being queried.
#
# 2026/09/23 21:09:58 INFO dspy.teleprompt.mipro_optimizer_v2:
#
# 2026/09/23 21:09:58 INFO dspy.teleprompt.mipro_optimizer_v2: ==> STEP 3: FINDING OPTIMAL PROMPT PARAMETERS <==
# 2026/09/23 21:09:58 INFO dspy.teleprompt.mipro_optimizer_v2: We will evaluate the program over a series of trials with different combinations of instructions and few-shot examples to find the optimal combination using Bayesian Optimization.
#
# 2026/09/23 21:09:58 INFO dspy.teleprompt.mipro_optimizer_v2: == Trial 1 / 10 - Full Evaluation of Default Program ==
# Average Metric: 10.00 / 12 (83.3%): 100%|██████████| 12/12 [00:00<00:00, 101.19it/s]
# 2026/09/23 21:09:58 INFO dspy.evaluate.evaluate: Average Metric: 10.0 / 12 (83.3%)
# 2026/09/23 21:09:58 INFO dspy.teleprompt.mipro_optimizer_v2: Default program score: 83.33
#
# 2026/09/23 21:09:58 INFO dspy.teleprompt.mipro_optimizer_v2: ===== Trial 2 / 10 =====
# Average Metric: 9.00 / 12 (75.0%): 100%|██████████| 12/12 [00:00<00:00, 100.97it/s]
# 2026/09/23 21:09:58 INFO dspy.evaluate.evaluate: Average Metric: 9.0 / 12 (75.0%)
# 2026/09/23 21:09:58 INFO dspy.teleprompt.mipro_optimizer_v2: Score: 75.0 with parameters ['Predictor 0: Instruction 1', 'Predictor 0: Few-Shot Set 1'].
# 2026/09/23 21:09:58 INFO dspy.teleprompt.mipro_optimizer_v2: Scores so far: [83.33, 75.0]
# 2026/09/23 21:09:58 INFO dspy.teleprompt.mipro_optimizer_v2: Best score so far: 83.33
# 2026/09/23 21:09:58 INFO dspy.teleprompt.mipro_optimizer_v2: ========================
#
#
# 2026/09/23 21:09:58 INFO dspy.teleprompt.mipro_optimizer_v2: ===== Trial 3 / 10 =====
# Average Metric: 10.00 / 12 (83.3%): 100%|██████████| 12/12 [00:00<00:00, 79.58it/s]
# 2026/09/23 21:09:59 INFO dspy.evaluate.evaluate: Average Metric: 10.0 / 12 (83.3%)
# 2026/09/23 21:09:59 INFO dspy.teleprompt.mipro_optimizer_v2: Score: 83.33 with parameters ['Predictor 0: Instruction 2', 'Predictor 0: Few-Shot Set 1'].
# 2026/09/23 21:09:59 INFO dspy.teleprompt.mipro_optimizer_v2: Scores so far: [83.33, 75.0, 83.33]
# 2026/09/23 21:09:59 INFO dspy.teleprompt.mipro_optimizer_v2: Best score so far: 83.33
# 2026/09/23 21:09:59 INFO dspy.teleprompt.mipro_optimizer_v2: ========================
#
#
# 2026/09/23 21:09:59 INFO dspy.teleprompt.mipro_optimizer_v2: ===== Trial 4 / 10 =====
# Average Metric: 10.00 / 12 (83.3%): 100%|██████████| 12/12 [00:00<00:00, 90.82it/s]
# 2026/09/23 21:09:59 INFO dspy.evaluate.evaluate: Average Metric: 10.0 / 12 (83.3%)
# 2026/09/23 21:09:59 INFO dspy.teleprompt.mipro_optimizer_v2: Score: 83.33 with parameters ['Predictor 0: Instruction 4', 'Predictor 0: Few-Shot Set 1'].
# 2026/09/23 21:09:59 INFO dspy.teleprompt.mipro_optimizer_v2: Scores so far: [83.33, 75.0, 83.33, 83.33]
# 2026/09/23 21:09:59 INFO dspy.teleprompt.mipro_optimizer_v2: Best score so far: 83.33
# 2026/09/23 21:09:59 INFO dspy.teleprompt.mipro_optimizer_v2: ========================
#
#
# 2026/09/23 21:09:59 INFO dspy.teleprompt.mipro_optimizer_v2: ===== Trial 5 / 10 =====
# Average Metric: 10.00 / 12 (83.3%): 100%|██████████| 12/12 [00:00<00:00, 95.78it/s]
# 2026/09/23 21:09:59 INFO dspy.evaluate.evaluate: Average Metric: 10.0 / 12 (83.3%)
# 2026/09/23 21:09:59 INFO dspy.teleprompt.mipro_optimizer_v2: Score: 83.33 with parameters ['Predictor 0: Instruction 2', 'Predictor 0: Few-Shot Set 1'].
# 2026/09/23 21:09:59 INFO dspy.teleprompt.mipro_optimizer_v2: Scores so far: [83.33, 75.0, 83.33, 83.33, 83.33]
# 2026/09/23 21:09:59 INFO dspy.teleprompt.mipro_optimizer_v2: Best score so far: 83.33
# 2026/09/23 21:09:59 INFO dspy.teleprompt.mipro_optimizer_v2: ========================
#
#
# 2026/09/23 21:09:59 INFO dspy.teleprompt.mipro_optimizer_v2: ===== Trial 6 / 10 =====
# Average Metric: 9.00 / 12 (75.0%): 100%|██████████| 12/12 [00:00<00:00, 93.43it/s]
# 2026/09/23 21:09:59 INFO dspy.evaluate.evaluate: Average Metric: 9.0 / 12 (75.0%)
# 2026/09/23 21:09:59 INFO dspy.teleprompt.mipro_optimizer_v2: Score: 75.0 with parameters ['Predictor 0: Instruction 4', 'Predictor 0: Few-Shot Set 3'].
# 2026/09/23 21:09:59 INFO dspy.teleprompt.mipro_optimizer_v2: Scores so far: [83.33, 75.0, 83.33, 83.33, 83.33, 75.0]
# 2026/09/23 21:09:59 INFO dspy.teleprompt.mipro_optimizer_v2: Best score so far: 83.33
# 2026/09/23 21:09:59 INFO dspy.teleprompt.mipro_optimizer_v2: ========================
#
#
# 2026/09/23 21:09:59 INFO dspy.teleprompt.mipro_optimizer_v2: ===== Trial 7 / 10 =====
# Average Metric: 10.00 / 12 (83.3%): 100%|██████████| 12/12 [00:00<00:00, 85.07it/s]
# 2026/09/23 21:09:59 INFO dspy.evaluate.evaluate: Average Metric: 10.0 / 12 (83.3%)
# 2026/09/23 21:09:59 INFO dspy.teleprompt.mipro_optimizer_v2: Score: 83.33 with parameters ['Predictor 0: Instruction 0', 'Predictor 0: Few-Shot Set 1'].
# 2026/09/23 21:09:59 INFO dspy.teleprompt.mipro_optimizer_v2: Scores so far: [83.33, 75.0, 83.33, 83.33, 83.33, 75.0, 83.33]
# 2026/09/23 21:09:59 INFO dspy.teleprompt.mipro_optimizer_v2: Best score so far: 83.33
# 2026/09/23 21:09:59 INFO dspy.teleprompt.mipro_optimizer_v2: ========================
#
#
# 2026/09/23 21:09:59 INFO dspy.teleprompt.mipro_optimizer_v2: ===== Trial 8 / 10 =====
# Average Metric: 11.00 / 12 (91.7%): 100%|██████████| 12/12 [00:00<00:00, 95.35it/s]
# 2026/09/23 21:10:00 INFO dspy.evaluate.evaluate: Average Metric: 11.0 / 12 (91.7%)
# 2026/09/23 21:10:00 INFO dspy.teleprompt.mipro_optimizer_v2: Best full score so far! Score: 91.67
# 2026/09/23 21:10:00 INFO dspy.teleprompt.mipro_optimizer_v2: Score: 91.67 with parameters ['Predictor 0: Instruction 4', 'Predictor 0: Few-Shot Set 4'].
# 2026/09/23 21:10:00 INFO dspy.teleprompt.mipro_optimizer_v2: Scores so far: [83.33, 75.0, 83.33, 83.33, 83.33, 75.0, 83.33, 91.67]
# 2026/09/23 21:10:00 INFO dspy.teleprompt.mipro_optimizer_v2: Best score so far: 91.67
# 2026/09/23 21:10:00 INFO dspy.teleprompt.mipro_optimizer_v2: ========================
#
#
# 2026/09/23 21:10:00 INFO dspy.teleprompt.mipro_optimizer_v2: ===== Trial 9 / 10 =====
# Average Metric: 10.00 / 12 (83.3%): 100%|██████████| 12/12 [00:00<00:00, 90.99it/s]
# 2026/09/23 21:10:00 INFO dspy.evaluate.evaluate: Average Metric: 10.0 / 12 (83.3%)
# 2026/09/23 21:10:00 INFO dspy.teleprompt.mipro_optimizer_v2: Score: 83.33 with parameters ['Predictor 0: Instruction 0', 'Predictor 0: Few-Shot Set 0'].
# 2026/09/23 21:10:00 INFO dspy.teleprompt.mipro_optimizer_v2: Scores so far: [83.33, 75.0, 83.33, 83.33, 83.33, 75.0, 83.33, 91.67, 83.33]
# 2026/09/23 21:10:00 INFO dspy.teleprompt.mipro_optimizer_v2: Best score so far: 91.67
# 2026/09/23 21:10:00 INFO dspy.teleprompt.mipro_optimizer_v2: ========================
#
#
# 2026/09/23 21:10:00 INFO dspy.teleprompt.mipro_optimizer_v2: ===== Trial 10 / 10 =====
# Average Metric: 10.00 / 12 (83.3%): 100%|██████████| 12/12 [00:00<00:00, 85.56it/s]
# 2026/09/23 21:10:00 INFO dspy.evaluate.evaluate: Average Metric: 10.0 / 12 (83.3%)
# 2026/09/23 21:10:00 INFO dspy.teleprompt.mipro_optimizer_v2: Score: 83.33 with parameters ['Predictor 0: Instruction 3', 'Predictor 0: Few-Shot Set 1'].
# 2026/09/23 21:10:00 INFO dspy.teleprompt.mipro_optimizer_v2: Scores so far: [83.33, 75.0, 83.33, 83.33, 83.33, 75.0, 83.33, 91.67, 83.33, 83.33]
# 2026/09/23 21:10:00 INFO dspy.teleprompt.mipro_optimizer_v2: Best score so far: 91.67
# 2026/09/23 21:10:00 INFO dspy.teleprompt.mipro_optimizer_v2: =========================
#
#
# 2026/09/23 21:10:00 INFO dspy.teleprompt.mipro_optimizer_v2: ===== Trial 11 / 10 =====
# Average Metric: 11.00 / 12 (91.7%): 100%|██████████| 12/12 [00:00<00:00, 71.97it/s]
# 2026/09/23 21:10:00 INFO dspy.evaluate.evaluate: Average Metric: 11.0 / 12 (91.7%)
# 2026/09/23 21:10:00 INFO dspy.teleprompt.mipro_optimizer_v2: Score: 91.67 with parameters ['Predictor 0: Instruction 4', 'Predictor 0: Few-Shot Set 4'].
# 2026/09/23 21:10:00 INFO dspy.teleprompt.mipro_optimizer_v2: Scores so far: [83.33, 75.0, 83.33, 83.33, 83.33, 75.0, 83.33, 91.67, 83.33, 83.33, 91.67]
# 2026/09/23 21:10:00 INFO dspy.teleprompt.mipro_optimizer_v2: Best score so far: 91.67
# 2026/09/23 21:10:00 INFO dspy.teleprompt.mipro_optimizer_v2: =========================
#
#
# 2026/09/23 21:10:00 INFO dspy.teleprompt.mipro_optimizer_v2: Returning best identified program with score 91.67!
# Average Metric: 11.00 / 12 (91.7%): 100%|██████████| 12/12 [00:00<00:00, 81.12it/s]
# 2026/09/23 21:10:00 INFO dspy.evaluate.evaluate: Average Metric: 11.0 / 12 (91.7%)
# MIPROv2 score: 91.67
# Improvement over baseline: +8.34
# Improvement over Bootstrap: +8.34

# %%
# What BootstrapFewShot changed: demos attached to the inner Predict
# (optimized_bootstrap.generate is the ChainOfThought; demos live on its .predict)
demos = optimized_bootstrap.generate.predict.demos
print(f"BootstrapFewShot attached {len(demos)} demos")
print("(a mix of self-generated traces that passed the metric (<=4) and")
print("labeled trainset examples (<=16) — the two max_*_demos knobs)\n")
for i, demo in enumerate(demos, 1):
    print(f"--- demo {i} ---")
    print(f"Q: {demo.question}")
    print(f"A: {demo.answer}\n")

print("=" * 50)
print("Instructions — BootstrapFewShot does NOT change these:")
print(optimized_bootstrap.generate.predict.signature.instructions)
# Out:
# BootstrapFewShot attached 16 demos
# (a mix of self-generated traces that passed the metric (<=4) and
# labeled trainset examples (<=16) — the two max_*_demos knobs)
#
# --- demo 1 ---
# Q: What is DSPy?
# A: DSPy is a framework for building and deploying data science pipelines.
#
# --- demo 2 ---
# Q: What is Fine-tuning?
# A: Fine-tuning adjusts a pre-trained model on a specific task to enhance its performance.
#
# --- demo 3 ---
# Q: What is DSPy?
# A: DSPy is a framework for building and deploying data science pipelines.
#
# --- demo 4 ---
# Q: What is DSPy?
# A: DSPy is a framework for building and deploying data science pipelines.
#
# --- demo 5 ---
# Q: What is Fine-tuning?
# A: Fine-tuning adapts a pre-trained model to a specific task.
#
# --- demo 6 ---
# Q: What is DSPy?
# A: DSPy is a framework for programming language models.
#
# --- demo 7 ---
# Q: What is Vector DB?
# A: Vector databases store embeddings for similarity search.
#
# --- demo 8 ---
# Q: What is Attention?
# A: Attention mechanisms let models focus on relevant tokens.
#
# --- demo 9 ---
# Q: What is Prompt Engineering?
# A: Prompt engineering is the art of writing effective prompts.
#
# --- demo 10 ---
# Q: What is DSPy?
# A: DSPy is a framework for programming language models.
#
# --- demo 11 ---
# Q: What is Fine-tuning?
# A: Fine-tuning adapts a pre-trained model to a specific task.
#
# --- demo 12 ---
# Q: What is RAG?
# A: Retrieval-Augmented Generation combines search with LLMs.
#
# --- demo 13 ---
# Q: What is Chain-of-Thought?
# A: CoT prompting asks the model to show its reasoning.
#
# --- demo 14 ---
# Q: What is Vector DB?
# A: Vector databases store embeddings for similarity search.
#
# --- demo 15 ---
# Q: What is Vector DB?
# A: Vector databases store embeddings for similarity search.
#
# --- demo 16 ---
# Q: What is Transformers?
# A: Transformers are neural networks based on self-attention.
#
# ==================================================
# Instructions — BootstrapFewShot does NOT change these:
# Answer questions with short factual responses.

# %%
# MIPROv2 rewrites INSTRUCTIONS as well as demos — inspect both artifacts
print("MIPROv2-optimized instructions (rewritten by the optimizer):")
print(optimized_mipro.generate.predict.signature.instructions)

mipro_demos = optimized_mipro.generate.predict.demos
print(f"\nMIPROv2 attached {len(mipro_demos)} demos:")
for i, demo in enumerate(mipro_demos[:2], 1):
    print(f"  demo {i}: {demo.question} -> {demo.answer[:60]}")
# Out:
# MIPROv2-optimized instructions (rewritten by the optimizer):
# Provide a clear and concise answer to the question, including a logical reasoning statement that supports your response. Ensure that the reasoning helps contextualize the answer, making it easier for the user to understand the concept being queried.
#
# MIPROv2 attached 4 demos:
#   demo 1: What is Attention? -> Attention is a mechanism that enables models to focus on spe
#   demo 2: What is DSPy? -> DSPy is a framework for programming language models.

# %%
# See the ACTUAL prompt the LM receives — demos rendered inline.
# Works for any compiled program; here with the BootstrapFewShot one:
optimized_bootstrap(question="What is Attention?")
dspy.inspect_history(n=1)  # the full message with [[ ## question ## ]] / [[ ## answer ## ]] blocks
# Out:
# [2026-09-23T21:11:05.149284]
#
# System message:
#
# Your input fields are:
# 1. `question` (str):
# Your output fields are:
# 1. `reasoning` (str):
# 2. `answer` (str):
# All interactions will be structured in the following way, with the appropriate values filled in.
#
# [[ ## question ## ]]
# {question}
#
# [[ ## reasoning ## ]]
# {reasoning}
#
# [[ ## answer ## ]]
# {answer}
#
# [[ ## completed ## ]]
# In adhering to this structure, your objective is:
#         Answer questions with short factual responses.
#
#
# User message:
#
# This is an example of the task, though some input or output fields are not supplied.
#
# [[ ## question ## ]]
# What is Fine-tuning?
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# Not supplied for this particular example.
#
# [[ ## answer ## ]]
# Fine-tuning adapts a pre-trained model to a specific task.
#
# [[ ## completed ## ]]
#
#
# User message:
#
# This is an example of the task, though some input or output fields are not supplied.
#
# [[ ## question ## ]]
# What is DSPy?
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# Not supplied for this particular example.
#
# [[ ## answer ## ]]
# DSPy is a framework for programming language models.
#
# [[ ## completed ## ]]
#
#
# User message:
#
# This is an example of the task, though some input or output fields are not supplied.
#
# [[ ## question ## ]]
# What is Vector DB?
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# Not supplied for this particular example.
#
# [[ ## answer ## ]]
# Vector databases store embeddings for similarity search.
#
# [[ ## completed ## ]]
#
#
# User message:
#
# This is an example of the task, though some input or output fields are not supplied.
#
# [[ ## question ## ]]
# What is Attention?
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# Not supplied for this particular example.
#
# [[ ## answer ## ]]
# Attention mechanisms let models focus on relevant tokens.
#
# [[ ## completed ## ]]
#
#
# User message:
#
# This is an example of the task, though some input or output fields are not supplied.
#
# [[ ## question ## ]]
# What is Prompt Engineering?
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# Not supplied for this particular example.
#
# [[ ## answer ## ]]
# Prompt engineering is the art of writing effective prompts.
#
# [[ ## completed ## ]]
#
#
# User message:
#
# This is an example of the task, though some input or output fields are not supplied.
#
# [[ ## question ## ]]
# What is DSPy?
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# Not supplied for this particular example.
#
# [[ ## answer ## ]]
# DSPy is a framework for programming language models.
#
# [[ ## completed ## ]]
#
#
# User message:
#
# This is an example of the task, though some input or output fields are not supplied.
#
# [[ ## question ## ]]
# What is Fine-tuning?
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# Not supplied for this particular example.
#
# [[ ## answer ## ]]
# Fine-tuning adapts a pre-trained model to a specific task.
#
# [[ ## completed ## ]]
#
#
# User message:
#
# This is an example of the task, though some input or output fields are not supplied.
#
# [[ ## question ## ]]
# What is RAG?
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# Not supplied for this particular example.
#
# [[ ## answer ## ]]
# Retrieval-Augmented Generation combines search with LLMs.
#
# [[ ## completed ## ]]
#
#
# User message:
#
# This is an example of the task, though some input or output fields are not supplied.
#
# [[ ## question ## ]]
# What is Chain-of-Thought?
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# Not supplied for this particular example.
#
# [[ ## answer ## ]]
# CoT prompting asks the model to show its reasoning.
#
# [[ ## completed ## ]]
#
#
# User message:
#
# This is an example of the task, though some input or output fields are not supplied.
#
# [[ ## question ## ]]
# What is Vector DB?
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# Not supplied for this particular example.
#
# [[ ## answer ## ]]
# Vector databases store embeddings for similarity search.
#
# [[ ## completed ## ]]
#
#
# User message:
#
# This is an example of the task, though some input or output fields are not supplied.
#
# [[ ## question ## ]]
# What is Vector DB?
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# Not supplied for this particular example.
#
# [[ ## answer ## ]]
# Vector databases store embeddings for similarity search.
#
# [[ ## completed ## ]]
#
#
# User message:
#
# This is an example of the task, though some input or output fields are not supplied.
#
# [[ ## question ## ]]
# What is Transformers?
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# Not supplied for this particular example.
#
# [[ ## answer ## ]]
# Transformers are neural networks based on self-attention.
#
# [[ ## completed ## ]]
#
#
# User message:
#
# [[ ## question ## ]]
# What is DSPy?
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# DSPy is a framework designed for creating and deploying data science pipelines efficiently. It helps streamline the process of building machine learning models by providing a structured approach to data handling and model development.
#
# [[ ## answer ## ]]
# DSPy is a framework for building and deploying data science pipelines.
#
# [[ ## completed ## ]]
#
#
# User message:
#
# [[ ## question ## ]]
# What is Fine-tuning?
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# Fine-tuning is the process of taking a pre-trained model and training it further on a specific dataset to improve its performance on a particular task.
#
# [[ ## answer ## ]]
# Fine-tuning adjusts a pre-trained model on a specific task to enhance its performance.
#
# [[ ## completed ## ]]
#
#
# User message:
#
# [[ ## question ## ]]
# What is DSPy?
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# DSPy is a framework designed for creating and deploying data science pipelines efficiently. It helps streamline the process of building machine learning models by providing a structured approach to data handling and model development.
#
# [[ ## answer ## ]]
# DSPy is a framework for building and deploying data science pipelines.
#
# [[ ## completed ## ]]
#
#
# User message:
#
# [[ ## question ## ]]
# What is DSPy?
#
#
# Assistant message:
#
# [[ ## reasoning ## ]]
# DSPy is a framework designed for creating and deploying data science pipelines efficiently. It helps streamline the process of building machine learning models by providing a structured approach to data handling and model development.
#
# [[ ## answer ## ]]
# DSPy is a framework for building and deploying data science pipelines.
#
# [[ ## completed ## ]]
#
#
# User message:
#
# [[ ## question ## ]]
# What is Attention?
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## answer ## ]]`, and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Response:
#
# [[ ## reasoning ## ]]
# Attention is a mechanism in neural networks that allows the model to focus on specific parts of the input data when making predictions, improving the context understanding by weighing the importance of different elements in the sequence.
#
# [[ ## answer ## ]]
# Attention mechanisms enable models to focus on relevant parts of the input data when making predictions.
#
# [[ ## completed ## ]]

# %% [markdown]
# ## 9. Saving and Reloading

# %%
# Save optimized program
optimized_mipro.save("optimized_qa.json")
print("✅ Saved to optimized_qa.json")

# Reload
loaded = SimpleQA()
loaded.load("optimized_qa.json")

# Verify it works
result = loaded(question="What is DSPy?")
print(f"\nReloaded program answer: {result.answer}")
# Out:
# ✅ Saved to optimized_qa.json
#
# Reloaded program answer: DSPy is an open-source framework for defining, training, and deploying machine learning workflows, particularly with a focus on integrating language models into applications.
